# %% [markdown]
# # Evaluation

# %% [markdown]
# This notebook will include the final evaluation and recommendations.

# %%
# import necessary libaries 
import pandas as pd
import numpy as np
# To display matplotlib plots inline in Jupyter Notebook
# %matplotlib inline
# For statistics operations
import statistics
# For data visualization using matplotlib
import matplotlib.pyplot as plt
# For data visualization using seaborn
import seaborn as sns

# %run '/Users/brittneynitta-lee/Desktop/Data_Science/Phase_5/Capstone_Project/Models.ipynb'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4315 entries, 0 to 4314
# Columns: 479 entries, ID to no_response
# dtypes: float64(251), int64(219), object(9)
# memory usage: 15.8+ MB
# The respondent IDs are not the same in both dataframes.
# ID                0
# samplegroup       0
# qzip              0
# q1                0
# q2a_1             0
#                ...
# Age_range2      303
# Age_range3      303
# Age2_range2    1127
# Age2_range3    1127
# INCOME            0
# Length: 85, dtype: int64
# ID             0
# samplegroup    0
# qzip           0
# q1             0
# q2a_1          0
#               ..
# POV400         0
# ethnicity      0
# q6R            0
# q20R           0
# INCOME         0
# Length: 81, dtype: int64
# True
# ID             0
# samplegroup    0
# qzip           0
# q1             0
# q2a_1          0
#               ..
# POV400         0
# ethnicity      0
# q6R            0
# q20R           0
# INCOME         0
# Length: 81, dtype: int64
# ...

# %% [markdown]
# # Feature importance

# %% [markdown]
# From the XGBoost model, the top 10 features were selected based on feature importance. The feature importance provides a score for each feature that indicates how useful or valuable each feature was in the build of the boosted decision trees within the model. The more a feature is used to make decisions, the higher its relative importance.
#
# [More information about Feature Importance in Gradient Boosting](https://notebook.community/minesh1291/MachineLearning/xgboost/feature_importance_v1)

# %% [markdown]
# # List of features

# %% [markdown]
# 1. `q6R`: How would you rate the adequacy of the internet connection and speeds in the place where you live when it comes to your ability to do the tasks you want and need to do on the internet?
#
#
# 2. `q2a_2`: Please tell us about the technology devices you have in the place where you live.  Does your household have one or more of each of these?
#
#
# 3. `q4_1`: What are all the ways you get internet in the place where you live?
#
#
# 4. `q7`: Q7. What is the download speed of the internet connection in the place where you live?  If you have more than one source, please select the fastest speed you have access to.
#
#
# 5. `q2a_5`: Please tell us about the technology devices you have in the place where you live.  Does your household have one or more of each of these?
#
#
# 6. `q12a_3`: Know of or use low cost internet service - Mobile Citizen / InterConnection:  $120 per year internet.
#
#
# 7. `q16c_16`: How often does anyone in your household  - Look for answers to computer problems online.
#
#
# 8. `INCOME`: Income categories
#
#
# 9. `q2bb_1`: Thinking about each type of device you have in the place where you live; how did your household get each type of device?
#
#
# 10. `samplegroup`: Sample group of survey respondents

# %%
# create new dataframe to include top 10 features
new_data = low_income_data[['q1', 'q6R', 'q2a_2', 'q4_1', 'q7', 'q2a_5', 'q12a_3', 'q16c_16', 
                            'INCOME', 'q2bb_1', 'samplegroup']].copy()

# %%
new_data
# Out:
#       q1  q6R  q2a_2  q4_1  q7  q2a_5  q12a_3  q16c_16  INCOME  q2bb_1  \
# 0      1    5      2     1   2      0       1        3       2       1
# 1      1    4      3     3   3      0       1        2       3       1
# 2      1    4      2     6  99      0       2        5       1       1
# 4      1    9      2     3  98      0       0        0       1       0
# 7      1    3      2     1   2      0       1        2       2       2
# ...   ..  ...    ...   ...  ..    ...     ...      ...     ...     ...
# 4295   1    4      2     4   4      0       1        1       1       1
# 4297   1    0      0     0   0      0       1        5       1       7
# 4301   1    4      2     2  99      0       1        4       2       1
# 4305   1    5      0     2  99      0       1        5       2       7
# 4309   1    4      2     3   2      0       3        2       3       1
#
#       samplegroup
# 0               1
# 1               4
# 2               1
# 4               3
# ...

# %% [markdown]
# # Visualizations

# %%
# Create graph for top feature selection 
counts = (new_data[['q1', 'q6R']]
              .groupby(['q1', 'q6R'])
              .size()
              .unstack('q1')
         )
internet_access = counts.sum(axis='columns')
props = counts.div(internet_access, axis='index')

# %%
# Internet connection Speeds 
fig, ax = plt.subplots(figsize=(10,6))
counts.plot.barh(color = ["green", "blue"], ax=ax)
ax.legend(
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5),
    labels = ["Yes", "No"],
    title='Internet Access')
plt.ylabel('Internet Connection')
plt.xlabel('Response Count')
# set y-axes tick labels
ax.set_yticklabels(["No Response", "Not Adequate", "Rarely Adequate",
                    "Sometimes Adequate", "Mostly Adequate", "Completely Adequate", "Don't access", "Not Applicable"])
plt.title('Internet Connection Speeds');

# %% [markdown]
# Although individuals without internet cannot respond to this survey question, the high response count for "Mostly Adequate" and "Completely Adequate" among those with internet access suggests that they are generally satisfied with their internet connection speeds.

# %%
# Create graph for top feature selection 
counts_2 = (new_data[['q1', 'q2a_2']]
              .groupby(['q1', 'q2a_2'])
              .size()
              .unstack('q1')
         )
devices = counts_2.sum(axis='columns')
props_1 = counts_2.div(devices, axis='index')

# %%
# Devices
fig, ax = plt.subplots(figsize=(10,6))
counts_2.plot.barh(color = ["green", "blue"], ax=ax)
ax.legend(
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5),
    labels = ["Yes", "No"],
    title='Internet Access')
plt.ylabel('Technology Devices')
plt.xlabel('Response Count')
# set y-axes tick labels
ax.set_yticklabels(["Desktop Computer", "Laptop Computer", "Smartphone or mobile phone", 
                    "Tablet", "Don't have in household"])
plt.title('Access to Devices');

# %% [markdown]
# All low-income survey respondents have access to devices and the highest count of devices are laptop computers, following desktop computers. Households who do not have internet access to have some type of device to access the internet.

# %%
# Create graph for top feature selection 
counts_3 = (new_data[['q1', 'q4_1']]
              .groupby(['q1', 'q4_1'])
              .size()
              .unstack('q1')
         )
access = counts_3.sum(axis='columns')
props_2 = counts_3.div(access, axis='index')

# %%
# Internet access
fig, ax = plt.subplots(figsize=(10,6))
counts_3.plot.barh(color = ["green", "blue"], ax=ax)
ax.legend(
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5),
    labels = ["Yes", "No"],
    title='Internet Access')
plt.ylabel('Internet Access')
plt.xlabel('Response Count')
# set y-axes tick labels
ax.set_yticklabels(["No Response", "Century Link DSL or Fiber Internet", "Wave Cable Internet", 
                    "Comcast Cable Internet", "Cellular Data Plan", "Provided by my building","Free or public Internet",
                   "Other", "Don't Access the internet where I live", "Share with a neighbor", "Don't Know"])
plt.title('Access to Internet');

# %% [markdown]
# Households who do have internet access in their home use Comcast as their service provider. A very small percentage of those who do access the internet in their home uses a Cellular Data plan.

# %%
# Create graph for top feature selection 
counts_4 = (new_data[['q1', 'q7']]
              .groupby(['q1', 'q7'])
              .size()
              .unstack('q1')
         )
download_speed = counts_4.sum(axis='columns')
props_4 = counts.div(download_speed, axis='index')

# %%
# Internet download speeds
fig, ax = plt.subplots(figsize=(10,6))
counts_4.plot.barh(color = ["green", "blue"], ax=ax)
ax.legend(
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5),
    labels = ["Yes", "No"],
    title='Internet Download Speed')
plt.ylabel('Internet Speeds')
plt.xlabel('Response Count')
# set y-axes tick labels
ax.set_yticklabels(["No Response", "Up to 15 Mbps", "Up to 25 Mbps", 
                    "Up to 100 Mbps", "Up to 1000 Mbps or 1 Gbps", "I do not have internet","Don't Know"])
plt.title('Internet Connection Download Speeds');

# %% [markdown]
# This is really interesting to see that majority of the survey respondents don't know their internet speed. But, those who do know have at the most 100 Mbps, which is not adequate for large household sizes.

# %%
# Create graph for top feature selection 
counts_5 = (new_data[['q1', 'INCOME']]
              .groupby(['q1', 'INCOME'])
              .size()
              .unstack('q1')
         )
income = counts_5.sum(axis='columns')
props_5 = counts_5.div(income, axis='index')

# %%
# Income data
fig, ax = plt.subplots(figsize=(10,6))
counts_5.plot.barh(color = ["green", "blue"], ax=ax)
ax.legend(
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5),
    labels = ["Yes", "No"],
    title='Internet Access')
plt.ylabel('Household Income')
plt.xlabel('Response Count')
# set y-axes tick labels
ax.set_yticklabels(["No Response","Below $25,000", "$25,000 - $49,000", "$50,000 - $74,999"])
plt.title('Household Income and Internet Access');

# %% [markdown]
# The low-income dataset comprises individuals in Seattle who responded to the survey. Most of these individuals have access to the internet, but the cost of internet services may be burdensome to their monthly income. Additionally, it is noteworthy that the majority of residents reported internet speeds of 100 Mbps provided by Comcast.

# %%
# Create graph for top feature selection 
counts_6 = (new_data[['q1', 'q12a_3']]
              .groupby(['q1', 'q12a_3'])
              .size()
              .unstack('q1')
         )
low_cost_internet = counts_6.sum(axis='columns')
props_6 = counts_6.div(low_cost_internet, axis='index')

# %%
# low-cost internet graph
fig, ax = plt.subplots(figsize=(10,6))
counts_6.plot.barh(color = ["green", "blue"], ax=ax)
ax.legend(
    loc='center left', 
    bbox_to_anchor=(1.05, 0.5),
    labels = ["Yes", "No"],
    title='Internet Access')
plt.ylabel('Response')
plt.xlabel('Response Count')
# set y-axes tick labels
ax.set_yticklabels(["No Response","Not aware of this offer", "Know about/Do not use", "Know about/ currently use"])
plt.title('Low-cost internet services');

# %% [markdown]
# The majority of respondents were unaware of the availability of affordable internet services. At that time, Mobile Citizen and InterConnection were providing internet services for $120 per year. The respondents who were unaware of this offer might be using internet services from other providers and possibly paying the full monthly price.

# %%
# Calculate the correlation matrix
corr_matrix = new_data.corr()

# Get the top 5 highest correlations
top_5_corr = corr_matrix.abs().unstack().sort_values(ascending=False).drop_duplicates()[:5]

# Print the top 5 highest correlations
print(top_5_corr)
# Out:
# samplegroup  samplegroup    1.000000
# q6R          q1             0.717681
# q2a_2        q2bb_1         0.501372
# q1           q4_1           0.403311
# q2a_2        q1             0.358883
# dtype: float64

# %% [markdown]
# These correlations suggest that there may be some relationships between the variables being studied. Specifically, q6R and q1 appear to be strongly correlated, while q2a_2 and q2bb_1 have a moderate positive correlation. The moderate correlation between q1 and q4_1 also suggests a possible relationship between these two variables. However, the weak correlation between q2a_2 and q1 indicates a less strong relationship between these two variables. Further analysis may be needed to fully understand the relationships between these variables.

# %% [markdown]
# # Recommendations

# %% [markdown]
# ### _Internet should be treated as a public utility_

# %% [markdown]
# I strongly recommend that Congress make the internet a public utility, especially in light of the COVID-19 pandemic. The data may be from 2018, but the pandemic has underscored the importance of affordable and universal internet access. Without access, individuals are left behind in society and are unable to access essential services such as healthcare, education, work and more.
#
# Here are my other recommendations:
#
# 1. Survey should be conducted in multiple languages
# 2. Look into free in-unit connectivity for low-income households
# 3. Bring awareness to free or low-cost internet programs
# 4. Limit the number of survey questions

# %% [markdown]
# # Next Steps

# %% [markdown]
# To bridge the digital gap among low-income households, it is imperative to collect comprehensive data from all such households in the US. This will enable Congress to take proactive steps towards providing free internet access to these households, complete with sufficient download speeds that are tailored to their respective household sizes and number of devices.

# %% [markdown]
# # For more information

# %% [markdown]
# Contact Brittney Nitta-Lee at bnittalee@gmail.com
